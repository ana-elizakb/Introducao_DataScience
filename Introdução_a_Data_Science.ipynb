# %% [markdown]
# <a href="https://colab.research.google.com/github/ana-elizakb/Introducao_DataScience/blob/main/Introdu%C3%A7%C3%A3o_a_Data_Science.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Analisando notas em geral

# %%
import pandas as pd
notas = pd.read_csv("ratings.csv")
notas.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
notas.columns = ["usuarioID", "filmeID", "nota", "momento"]
notas.head()
# Out:
#    usuarioID  filmeID  nota    momento
# 0          1        1   4.0  964982703
# 1          1        3   4.0  964981247
# 2          1        6   4.0  964982224
# 3          1       47   5.0  964983815
# 4          1       50   5.0  964982931

# %%
notas.nota.unique()
notas.nota.value_counts()
# Out:
# nota
# 4.0    26818
# 3.0    20047
# 5.0    13211
# 3.5    13136
# 4.5     8551
# 2.0     7551
# 2.5     5550
# 1.0     2811
# 1.5     1791
# 0.5     1370
# Name: count, dtype: int64

# %%
print("Média:",notas.nota.mean())
print("Mediana:",notas.nota.median())
# Out:
# Média: 3.501556983616962
# Mediana: 3.5

# %% [markdown]
# #Analisando os filmes

# %%
filmes = pd.read_csv("movies.csv")
filmes.columns = ["filmeID","titulos", "generos"]
filmes.head()
# Out:
#    filmeId                             titulos  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                        generos
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %% [markdown]
# #Analisando notas específicas por filme

# %%
notas.query("filmeID==1").nota.mean()
# Out:
# 3.9209302325581397

# %%
notas.query("filmeID==2").nota.mean()
# Out:
# 3.4318181818181817

# %%
medias_por_filme = notas.groupby("filmeID").mean().nota
medias_por_filme
# Out:
# filmeID
# 1         3.920930
# 2         3.431818
# 3         3.259615
# 4         2.357143
# 5         3.071429
#             ...
# 193581    4.000000
# 193583    3.500000
# 193585    3.500000
# 193587    3.500000
# 193609    4.000000
# Name: nota, Length: 9724, dtype: float64

# %%
medias_por_filme.plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
medias_por_filme.describe()
# Out:
# count    9724.000000
# mean        3.262448
# std         0.869874
# min         0.500000
# 25%         2.800000
# 50%         3.416667
# 75%         3.911765
# max         5.000000
# Name: nota, dtype: float64
